# %%
import numpy as np
import pandas as pd
import networkx as nx
import re
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %% [markdown]
# ## Read the book metadata dataset

# %%
df = pd.read_parquet('metadata_en.parquet')
df
# Out:
#                                                    title  \
# 1                                      The Master Spirit
# 2                                   The Family on Wheels
# 3      Three Good Giants\nWhose Ancient Deeds are rec...
# 4      Drake's Road Book of the Grand Junction Railwa...
# 5      Facts and Speculations on the Origin and Histo...
# ...                                                  ...
# 74677  Reform and Politics\r\nPart 2 from The Works o...
# 74678  The Speedwell Boys and Their Ice Racer; Or, Lo...
# 74680                     The Starling: A Scottish Story
# 74682  Chronicles of England, Scotland and Ireland (2...
# 74683                The Love Sonnets of a Car Conductor
#
#                                      creator birthdate deathdate  \
# 1                       Magnay, William, Sir      1855      1917
# 2      Oxley, J. Macdonald (James Macdonald)      1855      1907
# 3                         Rabelais, François      1835      1901
# 4                  Drake, James, active 1825      None      None
# 5                     Chatto, William Andrew      1799      1864
# ...                                      ...       ...       ...
# 74677               Whittier, John Greenleaf      1807      1892
# 74678                          Rockwood, Roy      None      None
# 74680                        Macleod, Norman      1812      1872
# 74682                     Holinshed, Raphael      None      None
# 74683                         Irwin, Wallace      1876      1959
#
#                publisher      issued                     rights language  \
# 1      Project Gutenberg  2022-03-25  Public domain in the USA.       en
# 2      Project Gutenberg  2017-11-05  Public domain in the USA.       en
# 3      Project Gutenberg  2019-04-09  Public domain in the USA.       en
# 4      Project Gutenberg  2013-07-31  Public domain in the USA.       en
# 5      Project Gutenberg  2014-05-04  Public domain in the USA.       en
# ...                  ...         ...                        ...      ...
# 74677  Project Gutenberg  2005-12-01  Public domain in the USA.       en
# 74678  Project Gutenberg  2015-06-07  Public domain in the USA.       en
# 74680  Project Gutenberg  2013-02-12  Public domain in the USA.       en
# 74682  Project Gutenberg  2005-09-25  Public domain in the USA.       en
# 74683  Project Gutenberg  2004-03-01  Public domain in the USA.       en
#
#                                                 subjects  \
# 1      [London (England) -- Fiction, Love stories, Ad...
# 2      [Orphans -- Juvenile fiction, Siblings -- Juve...
# 3      [Fantasy fiction, Conduct of life -- Juvenile ...
# 4      [Grand Junction Railway Company (Great Britain...
# 5                         [Playing cards -- History, GV]
# ...                                                  ...
# 74677     [United States -- Politics and government, PS]
# 74678               [Iceboating -- Juvenile fiction, PZ]
# 74680  [Clergy -- Fiction, Villages -- Fiction, Scotl...
# 74682  [Great Britain -- History -- Tudors, 1485-1603...
# 74683  [Humorous poetry, American, Sonnets, Street-ra...
#
#                                              description  Index
# 1      [Reading ease score: 71.3 (7th grade). Fairly ...  67703
# 2      [Reading ease score: 77.9 (7th grade). Fairly ...  55891
# 3      [Reading ease score: 76.2 (7th grade). Fairly ...  59235
# 4      [Reading ease score: 65.5 (8th & 9th grade). N...  43367
# 5      [Reading ease score: 62.7 (8th & 9th grade). N...  45584
# ...                                                  ...    ...
# 74677  [Reading ease score: 49.7 (College-level). Dif...   9596
# 74678  [Reading ease score: 83.7 (6th grade). Easy to...  49162
# 74680  [Reading ease score: 78.4 (7th grade). Fairly ...  41989
# 74682  [Reading ease score: 58.5 (10th to 12th grade)...  16749
# 74683  [Reading ease score: 78.8 (7th grade). Fairly ...   5332
#
# [59852 rows x 11 columns]

# %% [markdown]
# Basic information about the dataset

# %%
print(f"Dataframe's shape: {df.shape}\n")
print(df.info())
# Out:
# Dataframe's shape: (59852, 11)
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59852 entries, 1 to 74683
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        59847 non-null  object
#  1   creator      59698 non-null  object
#  2   birthdate    49715 non-null  object
#  3   deathdate    48613 non-null  object
#  4   publisher    59852 non-null  object
#  5   issued       59852 non-null  object
#  6   rights       59852 non-null  object
#  7   language     59852 non-null  object
#  8   subjects     59852 non-null  object
#  9   description  59852 non-null  object
#  10  Index        59852 non-null  object
# dtypes: object(11)
# memory usage: 5.5+ MB
# None

# %% [markdown]
# ## Data Preprocessing

# %%
print("Birthdate's unique values:\n", df['birthdate'].unique())
print("Deathdate's unique values:\n", df['deathdate'].unique())
# Out:
# Birthdate's unique values:
#  ['1855' '1835' None '1799' '1836' '1873' '1804' '1803' '1837' '1911'
#  '1859' '1812' '1865' '1813' '1851' '1849' '1862' '1879' '1846' '1860'
#  '1885' '1872' '1822' '1910' '1814' '1876' '1893' '1903' '1882' '1852'
#  '1785' '1838' '1877' '1834' '1824' '1870' '1861' '1802' '1868' '1842'
#  '1892' '1858' '1664' '1866' '1880' '1867' '1881' '1854' '1841' '1839'
#  '1856' '1848' '1853' '1875' '1863' '1828' '1871' '1772' '1923' '1830'
#  '1751' '1889' '1794' '1831' '1899' '1878' '1925' '1922' '1753' '1832'
#  '1883' '1633' '1817' '1907' '1811' '1845' '1869' '1747' '1850' '1971'
#  '1833' '1717' '1914' '1826' '1840' '1930' '1791' '1810' '1801' '1844'
#  '1564' '1928' '1857' '1792' '1901' '1787' '1703' '1821' '1888' '1827'
#  '1819' '1890' '1805' '1809' '1843' '1797' '1783' '1820' '1776' '1641'
#  '1511' '1864' '1912' '1823' '1886' '1927' '1847' '1789' '1469' '1806'
#  '1755' '1497' '1829' '1894' '1760' '1897' '1775' '-431' '1527' '1896'
#  '1807' '1796' '1887' '1771' '1728' '1918' '1825' '1947' '1584' '120'
#  '973' '1712' '1670' '1793' '1931' '1704' '1915' '1759' '1723' '1904'
#  '1749' '1547' '1688' '1902' '1874' '1818' '1933' '1884' '1651' '1920'
#  '1795' '1745' '1798' '1621' '1909' '204' '1929' '1905' '1693' '1815'
#  '1697' '1561' '1630' '1908' '1961' '1609' '1790' '1895' '1265' '1957'
#  '1917' '1916' '1562' '1816' '1788' '1743' '1782' '1766' '1724' '1769'
#  '1694' '1808' '1779' '1898' '1926' '1778' '1946' '1913' '1767' '1667'
#  '1921' '1730' '46' '1713' '1656' '1726' '1452' '1573' '1631' '1720'
#  '-428' '1784' '1754' '-384' '1729' '1800' '1684' '1919' '1746' '1777'
#  '1287' '1937' '1725' '23' '1709' '-54' '1951' '1949' '1786' '1645' '1780'
#  '1732' '20' '1958' '675' '1758' '1770' '1737' '1702' '1906' '-450' '1686'
#  '1935' '1347' '1090' '1714' '1569' '1342' '1676' '1942' '1900' '-43'
#  '-65' '1924' '1733' '56' '184' '-99' '1588' '1738' '1613' '1742' '1669'
#  '1380' '1652' '1079' '1774' '1932' '1675' '1555' '1960' '1721' '1773'
#  '1934' '1622' '1674' '1970' '1716' '1503' '1478' '1948' '1653' '1891'
#  '1632' '1763' '1639' '1757' '1727' '1740' '1657' '1640' '1490' '1781'
#  '1617' '1509' '1608' '1707' '1711' '-750' '1689' '1761' '1475' '1591'
#  '1764' '1558' '1642' '1590' '1579' '1696' '1756' '-551' '1523' '1768'
#  '1734' '1682' '1578' '1666' '1470' '1752' '1678' '1938' '1343' '-86'
#  '1710' '-525' '-254' '-58' '1945' '1304' '1718' '1762' '1941' '1533'
#  '1936' '1409' '1956' '1611' '1492' '-70' '1706' '-106' '1672' '1668'
#  '1601' '1943' '1053' '1692' '1950' '1628' '1765' '1662' '1483' '1741'
#  '1572' '480' '1254' '39' '1574' '1736' '1554' '1748' '1510' '1654' '1735'
#  '1650' '1685' '1715' '1719' '1615' '1616' '354' '1600' '1955' '1620'
#  '1173' '1596' '1207' '1722' '1567' '1963' '1539' '1627' '1524' '365'
#  '1331' '-84' '1566' '1553' '-460' '1471' '950' '1583' '1739' '1560'
#  '1944' '1655' '1744' '1363' '1626' '1534' '1648' '1677' '1577' '1671'
#  '1635' '121' '1939' '1634' '-95' '1515' '1731' '1313' '1580' '1681'
#  '1451' '1644' '1750' '61' '-300' '1708' '1981' '37' '1683' '1625' '1629'
#  '1623' '1691' '1952' '1549' '1687' '1516' '1544' '1679' '-496' '1545'
#  '1496' '1969' '1551' '1499' '1673' '1614' '1964' '1500' '1605' '1575'
#  '1466' '980' '-522' '1568' '55' '1170' '1458' '1505' '1457' '1058' '1587'
#  '1530' '1048' '1638' '-445' '1604' '1593' '1606' '673' '1484' '1571'
#  '331' '1607' '484' '1474' '1612' '1705' '1491' '1660' '1618' '1647'
#  '1518' '1624' '1126' '1130' '1699' '348' '1548' '1522' '412' '1540'
#  '1582' '-484' '1603' '1440' '1680' '1056' '1940' '1658' '1599' '1646'
#  '1586' '1150' '1661' '1953' '1570' '1559' '1619' '1982' '1954' '1214'
#  '-234' '1529' '1135' '1595' '1659' '1695' '1690' '1563' '1414' '1663'
#  '-440' '1959' '1576' '1698' '-63' '1494' '-290' '-371' '1493' '1407'
#  '1602' '1520' '1592']
# Deathdate's unique values:
#  ['1917' '1907' '1901' None '1864' '1961' '1895' '1898' '1981' '1927'
#  '1870' '1914' '1874' '1920' '1909' '1943' '1934' '1930' '1924' '1887'
#  '1971' '1890' '1953' '1963' '1994' '1946' '1896' '1925' '1873' '1962'
#  '1922' '1906' '1918' '1871' '1979' '1726' '1944' '1940' '1903' '1937'
#  '1974' '1919' '1893' '1950' '1908' '1939' '1936' '1931' '1897' '1889'
#  '1958' '1970' '1952' '1996' '1876' '1933' '1945' '1816' '1941' '1928'
#  '1892' '1976' '1990' '2005' '1831' '1899' '1879' '1703' '1949' '1880'
#  '1872' '1935' '1921' '1822' '1932' '1957' '1797' '1975' '1916' '1911'
#  '1859' '1857' '1891' '2000' '1852' '1863' '1947' '1881' '1882' '1877'
#  '1850' '1616' '2008' '1938' '1948' '1894' '1915' '1878' '1884' '1966'
#  '1942' '1972' '1764' '1956' '1854' '1951' '1913' '1973' '1274' '1862'
#  '1959' '1707' '1574' '2001' '1987' '1929' '1866' '1536' '1993' '1731'
#  '1904' '1836' '1900' '1967' '1818' '1849' '1851' '-355' '1885' '1926'
#  '1608' '1875' '2014' '1902' '1954' '1845' '1964' '1832' '1779' '1867'
#  '1910' '1923' '1997' '1848' '1905' '180' '1057' '1800' '1969' '1729'
#  '2004' '1888' '1796' '1806' '1776' '1772' '1965' '1988' '1883' '1912'
#  '2010' '1968' '1827' '1869' '1985' '1886' '1715' '2022' '1960' '1820'
#  '1695' '270' '1860' '2002' '1769' '1626' '1778' '1534' '2021' '1701'
#  '2006' '1657' '1843' '1810' '1855' '1986' '1865' '1977' '1838' '1995'
#  '1789' '1980' '1321' '1846' '1774' '1982' '1955' '1635' '1858' '1826'
#  '1837' '1828' '1804' '1834' '1840' '1773' '1835' '1647' '1839' '1824'
#  '1998' '1992' '2003' '1733' '2013' '1823' '1634' '1745' '1999' '1794'
#  '1817' '119' '1801' '1853' '1692' '1734' '1519' '1652' '1830' '1700'
#  '1683' '-348' '1809' '1780' '1983' '-322' '1815' '1802' '1605' '1861'
#  '-406' '1611' '2018' '1757' '2007' '1345' '2012' '1798' '79' '-19' '2011'
#  '1592' '1717' '2009' '1642' '1978' '66' '1768' '749' '1856' '1751' '-388'
#  '1744' '1805' '1784' '1380' '1813' '1153' '1770' '1400' '1984' '1792'
#  '1847' '17' '1675' '-8' '1807' '1627' '1844' '117' '253' '-43' '1679'
#  '1833' '1760' '1280' '1722' '1142' '1829' '1825' '1755' '1756' '1620'
#  '1614' '1771' '1758' '1527' '1673' '1637' '1718' '1556' '1535' '1723'
#  '1348' '1677' '1795' '1749' '1737' '1689' '1555' '1791' '1868' '1566'
#  '1593' '1564' '1674' '1720' '1742' '1788' '1821' '1989' '-650' '1761'
#  '1767' '1630' '1754' '1819' '1594' '1727' '1625' '1842' '2017' '1782'
#  '-479' '1596' '1743' '1296' '1538' '1648' '-34' '1799' '1543' '-456'
#  '1803' '-184' '16' '1374' '1699' '1473' '1549' '1783' '2020' '1790'
#  '1719' '1747' '1667' '1775' '1752' '1688' '1793' '1741' '1546' '1631'
#  '524' '1324' '1698' '65' '1748' '1325' '1811' '1586' '1573' '1705' '1640'
#  '1408' '1812' '1560' '1841' '1711' '1691' '1709' '1732' '2019' '430'
#  '1599' '1785' '1681' '1814' '1706' '1263' '1650' '1273' '1624' '1808'
#  '1753' '2015' '1453' '1622' '1349' '1590' '427' '1471' '1415' '2016'
#  '-53' '1615' '1786' '1712' '-395' '1528' '1019' '1621' '1738' '1787'
#  '1430' '1991' '1697' '1690' '1746' '1644' '1713' '1759' '1777' '1724'
#  '2023' '1386' '606' '-55' '1572' '1375' '1645' '1521' '265' '1512' '1601'
#  '1316' '-260' '1765' '1678' '1762' '1704' '1766' '1763' '1676' '1662'
#  '1558' '1623' '1687' '1603' '1685' '1618' '1632' '1781' '1584' '1725'
#  '1641' '1582' '1403' '1672' '1682' '1656' '1680' '1646' '1533' '1037'
#  '-446' '1185' '1639' '135' '1653' '1638' '1219' '1526' '1736' '909'
#  '1664' '1111' '1696' '1122' '-380' '1670' '1669' '1294' '1448' '735'
#  '1529' '235' '363' '1241' '580' '1571' '1661' '1658' '1384' '1716' '1554'
#  '397' '1198' '632' '1694' '1693' '1190' '1666' '1600' '1606' '1613' '840'
#  '485' '1710' '1581' '1750' '1143' '-430' '1494' '1530' '1133' '1708'
#  '1684' '1289' '1654' '1518' '1730' '1671' '1395' '1212' '1649' '1636'
#  '1655' '1284' '-149' '1498' '1204' '1468' '1633' '1587' '1562' '1492'
#  '1728' '1539' '1629' '1735' '1595' '1547' '-381' '407' '1580' '1568'
#  '1540' '1665' '1491' '14' '-212' '-287' '1541' '1457' '547' '1531']

# %%
df['birthdate'] = df['birthdate'].astype('Int64')
df['deathdate'] = df['deathdate'].astype('Int64')

print(df.info())

display(df[['birthdate', 'deathdate']].head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59852 entries, 1 to 74683
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        59847 non-null  object
#  1   creator      59698 non-null  object
#  2   birthdate    49715 non-null  Int64
#  3   deathdate    48613 non-null  Int64
#  4   publisher    59852 non-null  object
#  5   issued       59852 non-null  object
#  6   rights       59852 non-null  object
#  7   language     59852 non-null  object
#  8   subjects     59852 non-null  object
#  9   description  59852 non-null  object
#  10  Index        59852 non-null  object
# dtypes: Int64(2), object(9)
# memory usage: 5.6+ MB
# None
#    birthdate  deathdate
# 1       1855       1917
# 2       1855       1907
# 3       1835       1901
# 4       <NA>       <NA>
# 5       1799       1864

# %%
df['issued'] = pd.to_datetime(df['issued'])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59852 entries, 1 to 74683
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        59847 non-null  object
#  1   creator      59698 non-null  object
#  2   birthdate    49715 non-null  Int64
#  3   deathdate    48613 non-null  Int64
#  4   publisher    59852 non-null  object
#  5   issued       59852 non-null  datetime64[ns]
#  6   rights       59852 non-null  object
#  7   language     59852 non-null  object
#  8   subjects     59852 non-null  object
#  9   description  59852 non-null  object
#  10  Index        59852 non-null  object
# dtypes: Int64(2), datetime64[ns](1), object(8)
# memory usage: 5.6+ MB

# %%
print("Number of unique values in the publisher column: {0}".format(
    df['publisher'].unique().shape[0]
))
# Out:
# Number of unique values in the publisher column: 1

# %%
del df['publisher']

display(df.head())
# Out:
#                                                title  \
# 1                                  The Master Spirit
# 2                               The Family on Wheels
# 3  Three Good Giants\nWhose Ancient Deeds are rec...
# 4  Drake's Road Book of the Grand Junction Railwa...
# 5  Facts and Speculations on the Origin and Histo...
#
#                                  creator  birthdate  deathdate     issued  \
# 1                   Magnay, William, Sir       1855       1917 2022-03-25
# 2  Oxley, J. Macdonald (James Macdonald)       1855       1907 2017-11-05
# 3                     Rabelais, François       1835       1901 2019-04-09
# 4              Drake, James, active 1825       <NA>       <NA> 2013-07-31
# 5                 Chatto, William Andrew       1799       1864 2014-05-04
#
#                       rights language  \
# 1  Public domain in the USA.       en
# 2  Public domain in the USA.       en
# 3  Public domain in the USA.       en
# 4  Public domain in the USA.       en
# 5  Public domain in the USA.       en
#
#                                             subjects  \
# 1  [London (England) -- Fiction, Love stories, Ad...
# 2  [Orphans -- Juvenile fiction, Siblings -- Juve...
# 3  [Fantasy fiction, Conduct of life -- Juvenile ...
# 4  [Grand Junction Railway Company (Great Britain...
# 5                     [Playing cards -- History, GV]
#
#                                          description  Index
# 1  [Reading ease score: 71.3 (7th grade). Fairly ...  67703
# 2  [Reading ease score: 77.9 (7th grade). Fairly ...  55891
# 3  [Reading ease score: 76.2 (7th grade). Fairly ...  59235
# 4  [Reading ease score: 65.5 (8th & 9th grade). N...  43367
# 5  [Reading ease score: 62.7 (8th & 9th grade). N...  45584

# %%
print("Number of unique values in the language column: {0}".format(
    df['language'].unique().shape[0]
))
# Out:
# Number of unique values in the language column: 1

# %%
if 'language' in df.columns:
    del df['language']

    display(df.head())
# Out:
#                                                title  \
# 1                                  The Master Spirit
# 2                               The Family on Wheels
# 3  Three Good Giants\nWhose Ancient Deeds are rec...
# 4  Drake's Road Book of the Grand Junction Railwa...
# 5  Facts and Speculations on the Origin and Histo...
#
#                                  creator  birthdate  deathdate     issued  \
# 1                   Magnay, William, Sir       1855       1917 2022-03-25
# 2  Oxley, J. Macdonald (James Macdonald)       1855       1907 2017-11-05
# 3                     Rabelais, François       1835       1901 2019-04-09
# 4              Drake, James, active 1825       <NA>       <NA> 2013-07-31
# 5                 Chatto, William Andrew       1799       1864 2014-05-04
#
#                       rights  \
# 1  Public domain in the USA.
# 2  Public domain in the USA.
# 3  Public domain in the USA.
# 4  Public domain in the USA.
# 5  Public domain in the USA.
#
#                                             subjects  \
# 1  [London (England) -- Fiction, Love stories, Ad...
# 2  [Orphans -- Juvenile fiction, Siblings -- Juve...
# 3  [Fantasy fiction, Conduct of life -- Juvenile ...
# 4  [Grand Junction Railway Company (Great Britain...
# 5                     [Playing cards -- History, GV]
#
#                                          description  Index
# 1  [Reading ease score: 71.3 (7th grade). Fairly ...  67703
# 2  [Reading ease score: 77.9 (7th grade). Fairly ...  55891
# 3  [Reading ease score: 76.2 (7th grade). Fairly ...  59235
# 4  [Reading ease score: 65.5 (8th & 9th grade). N...  43367
# 5  [Reading ease score: 62.7 (8th & 9th grade). N...  45584

# %%
if 'description' in df.columns:
    reading_ease_scores = list()
    reading_ease_levels = list()

    for i, descriptions in enumerate(df['description']):
        score_found = False
        level_found = False
        
        for description in descriptions:
            if re.search("Reading ease score:", description):
                score_match = re.findall("Reading ease score: ([\d\.]+)", description)
                if score_match:
                    reading_ease_scores.append(float(score_match[0]))
                    score_found = True
                
                level_match = re.findall("Reading ease score:\s[\d\.]+\s\((.+)\)", description)
                if level_match:
                    reading_ease_levels.append(level_match[0])
                    level_found = True
        
        if not score_found:
            reading_ease_scores.append(None)
        if not level_found:
            reading_ease_levels.append(None)

    df['reading ease score'] = reading_ease_scores
    df['reading ease level'] = reading_ease_levels

    del df['description']

df.head()
# Out:
#                                                title  \
# 1                                  The Master Spirit
# 2                               The Family on Wheels
# 3  Three Good Giants\nWhose Ancient Deeds are rec...
# 4  Drake's Road Book of the Grand Junction Railwa...
# 5  Facts and Speculations on the Origin and Histo...
#
#                                  creator  birthdate  deathdate     issued  \
# 1                   Magnay, William, Sir       1855       1917 2022-03-25
# 2  Oxley, J. Macdonald (James Macdonald)       1855       1907 2017-11-05
# 3                     Rabelais, François       1835       1901 2019-04-09
# 4              Drake, James, active 1825       <NA>       <NA> 2013-07-31
# 5                 Chatto, William Andrew       1799       1864 2014-05-04
#
#                       rights  \
# 1  Public domain in the USA.
# 2  Public domain in the USA.
# 3  Public domain in the USA.
# 4  Public domain in the USA.
# 5  Public domain in the USA.
#
#                                             subjects  Index  \
# 1  [London (England) -- Fiction, Love stories, Ad...  67703
# 2  [Orphans -- Juvenile fiction, Siblings -- Juve...  55891
# 3  [Fantasy fiction, Conduct of life -- Juvenile ...  59235
# 4  [Grand Junction Railway Company (Great Britain...  43367
# 5                     [Playing cards -- History, GV]  45584
#
#    reading ease score reading ease level
# 1                71.3          7th grade
# 2                77.9          7th grade
# 3                76.2          7th grade
# 4                65.5    8th & 9th grade
# 5                62.7    8th & 9th grade

# %%
print(stats.kurtosis(df['reading ease score'], nan_policy='omit'))
# Out:
# 0.1676668769189571

# %%
df['subjects'] = df['subjects'].apply(lambda x: [item for sublist in [s.split(' -- ') for s in x] for item in sublist])

display(df[['title', 'subjects']].head())
# Out:
#                                                title  \
# 1                                  The Master Spirit
# 2                               The Family on Wheels
# 3  Three Good Giants\nWhose Ancient Deeds are rec...
# 4  Drake's Road Book of the Grand Junction Railwa...
# 5  Facts and Speculations on the Origin and Histo...
#
#                                             subjects
# 1  [London (England), Fiction, Love stories, Adve...
# 2  [Orphans, Juvenile fiction, Siblings, Juvenile...
# 3  [Fantasy fiction, Conduct of life, Juvenile fi...
# 4  [Grand Junction Railway Company (Great Britain...
# 5                       [Playing cards, History, GV]

# %%
from collections import Counter

subject_list = df['subjects'].dropna().explode()

subject_counts = Counter(subject_list)
subject_df = pd.DataFrame(subject_counts.items(), columns=['subject', 'count']).sort_values(by='count', ascending=False).reset_index(drop=True)
subject_indexing = {subject: idx for idx, subject in enumerate(subject_df['subject'])}


co_occurrence_matrix = np.zeros((subject_df.shape[0], subject_df.shape[0]))
for subjects in df['subjects'].dropna():
    subjects = [subject for subject in subjects if subject in subject_indexing]  # Filter subjects to those in the set
    for i in range(len(subjects)):
        for j in range(i + 1, len(subjects)):
            idx1 = subject_indexing[subjects[i]]
            idx2 = subject_indexing[subjects[j]]
            co_occurrence_matrix[idx1, idx2] += 1
            co_occurrence_matrix[idx2, idx1] += 1 

print(co_occurrence_matrix)
# Out:
# [[6.8750e+04 2.0400e+02 1.7010e+04 ... 0.0000e+00 0.0000e+00 0.0000e+00]
#  [2.0400e+02 8.9248e+04 5.3500e+02 ... 0.0000e+00 0.0000e+00 5.0000e+00]
#  [1.7010e+04 5.3500e+02 0.0000e+00 ... 0.0000e+00 0.0000e+00 0.0000e+00]
#  ...
#  [0.0000e+00 0.0000e+00 0.0000e+00 ... 0.0000e+00 0.0000e+00 0.0000e+00]
#  [0.0000e+00 0.0000e+00 0.0000e+00 ... 0.0000e+00 0.0000e+00 0.0000e+00]
#  [0.0000e+00 5.0000e+00 0.0000e+00 ... 0.0000e+00 0.0000e+00 0.0000e+00]]

# %%
import plotly.graph_objects as go

G = nx.Graph()


for subjects in df['subjects'].dropna().head(1000):
    for i, subject1 in enumerate(subjects):
        for subject2 in subjects[i+1:]:
            if G.has_edge(subject1, subject2):
                G[subject1][subject2]['weight'] += 1
            else:
                G.add_edge(subject1, subject2, weight=1)

G_filtered = nx.Graph((u, v, e) for u, v, e in G.edges(data=True) if e['weight'] > 5)

pos = nx.spring_layout(G_filtered, k=0.1, seed=42)

edge_x = []
edge_y = []
for edge in G_filtered.edges():
    x0, y0 = pos[edge[0]]
    x1, y1 = pos[edge[1]]
    edge_x.extend([x0, x1, None])
    edge_y.extend([y0, y1, None])

node_x = []
node_y = []
node_size = []
node_text = []
for node in G_filtered.nodes():
    x, y = pos[node]
    node_x.append(x)
    node_y.append(y)
    node_size.append(G_filtered.degree[node])
    node_text.append(f"{node}<br>Connections: {G_filtered.degree[node]}")

edge_trace = go.Scatter(
    x=edge_x,
    y=edge_y,
    line=dict(width=0.5, color='#888'),
    hoverinfo='none',
    mode='lines'
)

node_color = [np.log(degree + 1) for degree in node_size]  # Log scale for color
node_colorbar = [degree for degree in node_size]  # Original degree counts for colorbar ticks

node_trace = go.Scatter(
    x=node_x,
    y=node_y,
    mode='markers',
    hoverinfo='text',
    marker=dict(
        showscale=True,
        colorscale='YlGnBu',  # Color gradient for log-scaled hue
        size=10,              # Fixed node size (no change)
        color=node_color,     # Logarithmic scale for color
        colorbar=dict(
            thickness=15,
            title="Node Connections",
            tickvals=[np.log(i + 1) for i in range(1, max(node_size) + 1, int(max(node_size)/5))],  # Adjust ticks based on log scale
            ticktext=[str(i) for i in range(1, max(node_size) + 1, int(max(node_size)/5))],  # Display original counts on colorbar ticks
            xanchor='left',
            titleside='right'
        )
    ),
    text=node_text
)
fig = go.Figure(data=[edge_trace, node_trace],
                layout=go.Layout(
                    title='Interactive Tag Co-occurrence Network',
                    titlefont_size=16,
                    showlegend=False,
                    hovermode='closest',
                    margin=dict(b=0, l=0, r=0, t=40),
                    xaxis=dict(showgrid=False, zeroline=False),
                    yaxis=dict(showgrid=False, zeroline=False)
                ))

fig.show()
# Out:
# <div>                            <div id="33bf4f89-a2ff-4e8c-aeec-9715b8f47a56" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("33bf4f89-a2ff-4e8c-aeec-9715b8f47a56")) {                    Plotly.newPlot(                        "33bf4f89-a2ff-4e8c-aeec-9715b8f47a56",                        [{"hoverinfo":"none","line":{"color":"#888","width":0.5},"mode":"lines","x":[-0.004511255015445206,0.024865911118949764,null,-0.004511255015445206,0.010263256963580148,null,-0.004511255015445206,-0.015233744527144195,null,0.024865911118949764,0.030457884905893642,null,0.024865911118949764,0.0026921306791473183,null,0.024865911118949764,0.024865911118949764,null,0.024865911118949764,0.010263256963580148,null,0.024865911118949764,0.05858077460887327,null,0.024865911118949764,0.07122117657841213,null,0.024865911118949764,-0.006198648688303131,null,0.024865911118949764,0.02588336295170536,null,0.024865911118949764,-0.016977349208264474,null,0.024865911118949764,0.044514803326335194,null,0.024865911118949764,0.03831796703805381,null,0.024865911118949764,0.04033289866386156,null,0.024865911118949764,0.024564953073175935,null,0.024865911118949764,0.07794977817610597,null,0.024865911118949764,-0.01758921184890631,null,0.024865911118949764,0.04386658836700715,null,0.024865911118949764,0.10507466892475431,null,0.024865911118949764,-0.006573854902749156,null,0.024865911118949764,-0.015233744527144195,null,0.024865911118949764,-0.0013484202260439628,null,0.024865911118949764,0.02915980506127768,null,0.024865911118949764,0.038957873283726706,null,0.024865911118949764,-0.06029752124080861,null,0.024865911118949764,0.0033445611301238967,null,0.024865911118949764,0.05709682494030007,null,0.024865911118949764,-0.012788254827849722,null,0.024865911118949764,0.06288651092124543,null,0.024865911118949764,0.017144127695984838,null,0.024865911118949764,0.07261456657989115,null,0.024865911118949764,-0.02396398801426712,null,0.024865911118949764,0.008874394099952537,null,0.024865911118949764,0.0018562390096406721,null,0.024865911118949764,-0.017776446046810765,null,0.024865911118949764,-0.025962174860898343,null,0.024865911118949764,0.04438511071714016,null,0.024865911118949764,0.036116602470591,null,0.024865911118949764,0.06934707615306733,null,0.024865911118949764,0.13103237729566222,null,0.024865911118949764,0.08222515978672357,null,0.024865911118949764,0.0764702839122534,null,0.024865911118949764,0.10264515449930066,null,0.024865911118949764,-0.010337354734276718,null,0.024865911118949764,0.08689921436354851,null,0.024865911118949764,0.02313123590246543,null,0.024865911118949764,0.011362704986397732,null,0.024865911118949764,0.04574873308894888,null,0.024865911118949764,0.0012443851919351752,null,0.024865911118949764,0.11165503381463988,null,0.024865911118949764,-0.04810885258580084,null,0.024865911118949764,-0.03565366415628311,null,0.024865911118949764,0.004106898003880229,null,0.024865911118949764,0.09830035827974702,null,0.024865911118949764,-0.007250259846812817,null,0.024865911118949764,-0.05558090447828016,null,0.024865911118949764,0.05281062712791481,null,0.024865911118949764,0.058025995210092246,null,0.024865911118949764,-0.004447541629222836,null,0.024865911118949764,0.018289616869653143,null,0.024865911118949764,0.07115292410920603,null,0.024865911118949764,0.0026760885231446774,null,0.024865911118949764,-0.025087333396610914,null,0.024865911118949764,-0.022828739327573316,null,0.024865911118949764,-0.016580829575473494,null,0.024865911118949764,-0.027531195875802286,null,0.024865911118949764,0.11532019733816036,null,0.024865911118949764,-0.01741888844967698,null,0.024865911118949764,0.08910644703640841,null,0.024865911118949764,0.008467032844345093,null,0.024865911118949764,0.023914626955014614,null,0.0248659111189 ...
